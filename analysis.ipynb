# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import pandas as pd
import numpy as np

npart = 100
steps = 5000
# Replace 'your_file.csv' with the actual path to your CSV file
file_path = 'data.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

#Sample data
x = np.array([df['x'].iloc[i:i+npart].to_numpy() for i in np.arange(steps)])
y = np.array([df['y'].iloc[i:i+npart].to_numpy() for i in np.arange(steps)])
z = np.array([df['z'].iloc[i:i+npart].to_numpy() for i in np.arange(steps)])
etot = np.array(df['etot'].iloc[0:steps*npart:npart])
temp = np.array(df['temp'].iloc[0:steps*npart:npart])
print(np.shape(x))

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
i = 3
#ax.scatter(x[1], y[1], z[1], c='r', marker='o')
#ax.scatter(x[i], y[i], z[i], c='g', marker='o')
#ax.scatter(np.linspace(x[0], x[i], 10), np.linspace(y[0], y[i], 10), np.linspace(z[0], z[i], 10), c='b', s=1)
ax.plot(x[:,1][0:3], y[:,1][0:3], z[:,1][0:3])
# Set axis labels
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

# Show the plot
plt.show()
# Out:
# (5000, 100)

# %%
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(15, 5))
print(etot)
etot_cut = etot[etot < 500000000][0:1000]
ax[0].plot(range(etot_cut.size), etot_cut)
ax[0].set_ylim(0, 2)
ax[0].set_title('Energy')
temp_cut = temp[temp < 50000000][0:1000]
ax[1].plot(range(temp_cut.size), temp_cut)
ax[1].set_ylim(0, 2)
ax[1].set_title('Temperature')
None
# Out:
# [9.88460e-01 1.99738e+04 9.88459e-01 ... 3.27277e+05 3.40068e+05
#  2.99761e+05]

# %%
plt.plot(range(x.T[99].size), x.T[99])

# %%
np.argmin(np.min(x, axis = 1))
np.argmin(x[4901, :])
# Out:
# 87
